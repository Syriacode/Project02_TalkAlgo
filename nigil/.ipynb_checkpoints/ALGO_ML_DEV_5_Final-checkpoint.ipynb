# %% [markdown]
# ## PROJECT-2: PART-3 - Machine Learning: Artificial Neural Network

# %% [markdown]
# ---

# %%
# Initial imports
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
# Set a random seed for TensorFlow to allow reproducible testing results
#tf.random.set_seed(126)

# %%
# Read in data
df = pd.read_csv("Sentiment_Scores_1.csv")
sentiment_scores = df.dropna()
data = sentiment_scores.drop(columns=['Unnamed: 0','Stock','Date','JSON File Name'])
data.head()
# Out:
#    Buy/Sell  Sentiment Score
# 1         1          -0.4767
# 2         1           0.9075
# 3         1           0.5236
# 5         1           0.2023
# 6         1           0.9756

# %%
# Creating Feature and Target
X = data['Sentiment Score']
y = data['Buy/Sell']
# Creating training and testing datasets for logistic Regression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=79, 
                                                    )

# %%
# Define the model - deep neural net
number_inputs = 1
hidden_nodes_layer = 256

nn = Sequential()
#First hidden layer
nn.add(Dense(units=hidden_nodes_layer, input_dim=number_inputs, activation="relu"))
#Second hidden layer
nn.add(Dense(units=hidden_nodes_layer, activation="relu"))
#Third hidden layer
nn.add(Dense(units=hidden_nodes_layer, activation="relu"))
#Fourth hidden layer
nn.add(Dense(units=hidden_nodes_layer, activation="relu"))
#Output layer
nn.add(Dense(units=1, activation="relu"))


# Compile model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Printing Model Summary
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 198,145
# Trainable params: 198,145
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 8. Fit the model with `100` epochs.

# %%
# Fit the model
model = nn.fit(X_train, y_train, epochs=150)
# Out:
# Epoch 1/150
# 12/12 [==============================] - 1s 4ms/step - loss: 1.6968 - accuracy: 0.5323
# Epoch 2/150
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0989 - accuracy: 0.4464
# Epoch 3/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7637 - accuracy: 0.4673
# Epoch 4/150
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7275 - accuracy: 0.5482
# Epoch 5/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7272 - accuracy: 0.4854
# Epoch 6/150
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7200 - accuracy: 0.4375
# Epoch 7/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7004 - accuracy: 0.5160
# Epoch 8/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7065 - accuracy: 0.5051
# Epoch 9/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6936 - accuracy: 0.5213
# Epoch 10/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6877 - accuracy: 0.5556
# Epoch 11/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6925 - accuracy: 0.5357
# Epoch 12/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6968 - accuracy: 0.4556
# Epoch 13/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6893 - accuracy: 0.5585
# Epoch 14/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6950 - accuracy: 0.5337
# Epoch 15/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6890 - accuracy: 0.5488
# Epoch 16/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6904 - accuracy: 0.5217
# Epoch 17/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6933 - accuracy: 0.4972
# Epoch 18/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6915 - accuracy: 0.5221
# Epoch 19/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6909 - accuracy: 0.5227
# Epoch 20/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6927 - accuracy: 0.5119
# Epoch 21/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6910 - accuracy: 0.5272
# Epoch 22/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6950 - accuracy: 0.5256
# Epoch 23/150
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6909 - accuracy: 0.5278
# Epoch 24/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6885 - accuracy: 0.5460
# Epoch 25/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6910 - accuracy: 0.5216
# Epoch 26/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6811 - accuracy: 0.5660
# Epoch 27/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6914 - accuracy: 0.5220
# Epoch 28/150
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6967 - accuracy: 0.4943
# Epoch 29/150
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6972 - accuracy: 0.5247
# Epoch 30/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6934 - accuracy: 0.5048
# Epoch 31/150
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6840 - accuracy: 0.5450
# Epoch 32/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6906 - accuracy: 0.4956
# Epoch 33/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7043 - accuracy: 0.5076
# Epoch 34/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6989 - accuracy: 0.4922
# Epoch 35/150
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6984 - accuracy: 0.5261
# Epoch 36/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6881 - accuracy: 0.5437
# Epoch 37/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6841 - accuracy: 0.5421
# Epoch 38/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6925 - accuracy: 0.5223
# Epoch 39/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6895 - accuracy: 0.5138
# Epoch 40/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6855 - accuracy: 0.5454
# Epoch 41/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6947 - accuracy: 0.5330
# Epoch 42/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6931 - accuracy: 0.5161
# Epoch 43/150
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6869 - accuracy: 0.5203
# Epoch 44/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6941 - accuracy: 0.5105
# Epoch 45/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6807 - accuracy: 0.5460
# Epoch 46/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7033 - accuracy: 0.4590
# Epoch 47/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6908 - accuracy: 0.4872
# Epoch 48/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6845 - accuracy: 0.5023
# Epoch 49/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6832 - accuracy: 0.5646
# Epoch 50/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6890 - accuracy: 0.5288
# Epoch 51/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6945 - accuracy: 0.5146
# Epoch 52/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6906 - accuracy: 0.5000
# Epoch 53/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6895 - accuracy: 0.5222
# Epoch 54/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6954 - accuracy: 0.5196
# Epoch 55/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6891 - accuracy: 0.5377
# Epoch 56/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6978 - accuracy: 0.4787
# Epoch 57/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6877 - accuracy: 0.5185
# Epoch 58/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6995 - accuracy: 0.4475
# Epoch 59/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6871 - accuracy: 0.5390
# Epoch 60/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6897 - accuracy: 0.5197
# Epoch 61/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6886 - accuracy: 0.5360
# Epoch 62/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6883 - accuracy: 0.5223
# Epoch 63/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6806 - accuracy: 0.5690
# Epoch 64/150
# 12/12 [==============================] - ETA: 0s - loss: 0.6988 - accuracy: 0.51 - 0s 6ms/step - loss: 0.6960 - accuracy: 0.5217
# Epoch 65/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6923 - accuracy: 0.5406
# Epoch 66/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6941 - accuracy: 0.4725
# Epoch 67/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6951 - accuracy: 0.4890
# Epoch 68/150
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6965 - accuracy: 0.5429
# Epoch 69/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6845 - accuracy: 0.5061
# Epoch 70/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6852 - accuracy: 0.5452
# Epoch 71/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6863 - accuracy: 0.5776
# Epoch 72/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6989 - accuracy: 0.5243
# Epoch 73/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6897 - accuracy: 0.5144
# Epoch 74/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6863 - accuracy: 0.5530
# Epoch 75/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7008 - accuracy: 0.4938
# Epoch 76/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6889 - accuracy: 0.4998
# Epoch 77/150
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7015 - accuracy: 0.5260
# Epoch 78/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6944 - accuracy: 0.5258
# Epoch 79/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6859 - accuracy: 0.5308
# Epoch 80/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6825 - accuracy: 0.5236
# Epoch 81/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6864 - accuracy: 0.5186
# Epoch 82/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7003 - accuracy: 0.4510
# Epoch 83/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6916 - accuracy: 0.5332
# Epoch 84/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6964 - accuracy: 0.4693
# Epoch 85/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6842 - accuracy: 0.5622
# Epoch 86/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6930 - accuracy: 0.5065
# Epoch 87/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6954 - accuracy: 0.5144
# Epoch 88/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6939 - accuracy: 0.4876
# Epoch 89/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7006 - accuracy: 0.5118
# Epoch 90/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6901 - accuracy: 0.5455
# Epoch 91/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6978 - accuracy: 0.5141
# Epoch 92/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6909 - accuracy: 0.5415
# Epoch 93/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6879 - accuracy: 0.5165
# Epoch 94/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6915 - accuracy: 0.5220
# Epoch 95/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6952 - accuracy: 0.4695
# Epoch 96/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6877 - accuracy: 0.5585
# Epoch 97/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6878 - accuracy: 0.5246
# Epoch 98/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6989 - accuracy: 0.4977
# Epoch 99/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6882 - accuracy: 0.5309
# Epoch 100/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6745 - accuracy: 0.5846
# Epoch 101/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6879 - accuracy: 0.5480
# Epoch 102/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6837 - accuracy: 0.5475
# Epoch 103/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6909 - accuracy: 0.5037
# Epoch 104/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6912 - accuracy: 0.5051
# Epoch 105/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6940 - accuracy: 0.4753
# Epoch 106/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6901 - accuracy: 0.5343
# Epoch 107/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6895 - accuracy: 0.5248
# Epoch 108/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6914 - accuracy: 0.5341
# Epoch 109/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6887 - accuracy: 0.5229
# Epoch 110/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6878 - accuracy: 0.5256
# Epoch 111/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6896 - accuracy: 0.5122
# Epoch 112/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6863 - accuracy: 0.5361
# Epoch 113/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6962 - accuracy: 0.4547
# Epoch 114/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6874 - accuracy: 0.5307
# Epoch 115/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6918 - accuracy: 0.5041
# Epoch 116/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6894 - accuracy: 0.5466
# Epoch 117/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7029 - accuracy: 0.5157
# Epoch 118/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6845 - accuracy: 0.5345
# Epoch 119/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7026 - accuracy: 0.5210
# Epoch 120/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6933 - accuracy: 0.5348
# Epoch 121/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6943 - accuracy: 0.5023
# Epoch 122/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6836 - accuracy: 0.5426
# Epoch 123/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6879 - accuracy: 0.5151
# Epoch 124/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6901 - accuracy: 0.5540
# Epoch 125/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6861 - accuracy: 0.5102
# Epoch 126/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6903 - accuracy: 0.4923
# Epoch 127/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6859 - accuracy: 0.5271
# Epoch 128/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6843 - accuracy: 0.5253
# Epoch 129/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6935 - accuracy: 0.4908
# Epoch 130/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6982 - accuracy: 0.4456
# Epoch 131/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6911 - accuracy: 0.5208
# Epoch 132/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6845 - accuracy: 0.4858
# Epoch 133/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6898 - accuracy: 0.5188
# Epoch 134/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6835 - accuracy: 0.5354
# Epoch 135/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6848 - accuracy: 0.5244
# Epoch 136/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6912 - accuracy: 0.4878
# Epoch 137/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6889 - accuracy: 0.4724
# Epoch 138/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6908 - accuracy: 0.5411
# Epoch 139/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6877 - accuracy: 0.5272
# Epoch 140/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6890 - accuracy: 0.5247
# Epoch 141/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6888 - accuracy: 0.5241
# Epoch 142/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6953 - accuracy: 0.4916
# Epoch 143/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6876 - accuracy: 0.5401
# Epoch 144/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6869 - accuracy: 0.4824
# Epoch 145/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6876 - accuracy: 0.5280
# Epoch 146/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6938 - accuracy: 0.5118
# Epoch 147/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6853 - accuracy: 0.5056
# Epoch 148/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6871 - accuracy: 0.5426
# Epoch 149/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6925 - accuracy: 0.5130
# Epoch 150/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6916 - accuracy: 0.5254

# %% [markdown]
# 9. Plot the loss function and accuracy.

# %%
# Evaluate the model fit with linear dummy data
model_loss, model_accuracy = nn.evaluate(X_test, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 4/4 - 0s - loss: 0.6715 - accuracy: 0.6098
# Loss: 0.6715402603149414, Accuracy: 0.6097561120986938

# %%
# Create a dataframe with the history dictionary
df_plot = pd.DataFrame(model.history, index=range(1, len(model.history["loss"]) + 1))

# %%
df_plot
# Out:
#          loss  accuracy
# 1    1.144005  0.517711
# 2    0.927968  0.485014
# 3    0.751509  0.498638
# 4    0.746535  0.495913
# 5    0.723490  0.474114
# ..        ...       ...
# 146  0.687995  0.534060
# 147  0.693506  0.514986
# 148  0.689263  0.523161
# 149  0.688757  0.523161
# 150  0.690727  0.523161
#
# [150 rows x 2 columns]

# %%
# Plot the loss
df_plot.plot(y="loss")

# %%
# Plot the accuracy
df_plot.plot(y="accuracy")
